# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\archive (26)\malnutrition_data (1).csv")
print(df.head())
# Out:
#    age_months  weight_kg   height_cm    muac_cm   bmi nutrition_status
# 0   12.345052   3.000000   54.134002  13.160919  10.0           normal
# 1   30.807200   5.459076   76.199180  13.944380  10.0           normal
# 2   15.723226   3.000000   60.280820  13.243565  10.0           normal
# 3   57.796256  10.103074  104.990471  14.105683  10.0           normal
# 4   40.321320   7.110583   85.277902  14.641630  10.0           normal

# %%
print(df.isnull().sum())
# Out:
# age_months          0
# weight_kg           0
# height_cm           0
# muac_cm             0
# bmi                 0
# nutrition_status    0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
print(df.head())
# Out:
#     ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0  100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1  101   Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2  102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3  103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4  104   Customer_104  ORD-93614  10/20/2025      Biography        Books
#
#   Quantity   Price    Payment_Method      Status    Total
# 0        3      38  Cash on Delivery     Shipped   114.00
# 1        2     abd            PayPal  Processing      NaN
# 2        1  389.05            PayPal   Delivered   389.05
# 3        5  233.92            PayPal  Processing  1169.60
# 4        1  552.51  Cash on Delivery  Processing   552.51

# %%
print(df.isnull().sum())
# Out:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
print("Missing values before cleaning:")
print(df.isnull().sum())
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
df["Price"] = df["Price"].fillna(df["Price"].mean())
df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])
print("\nMissing values after cleaning:")
print(df.isnull().sum())
print(df.head())
df.to_csv("sales_cleaned.csv", index=False)
print("\nData cleaned successfully!")
# Out:
# Missing values before cleaning:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
print("Missing values before cleaning:")
print(df.isnull().sum())
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
df["Price"] = df["Price"].fillna(df["Price"].mean())
df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])
print("\nMissing values after cleaning:")
print(df.isnull().sum())
print(df.head())
df.to_csv("sales_cleaned.csv", index=False)
print("\nData cleaned successfully!")
# Out:
# Missing values before cleaning:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
print("Missing values before cleaning:")
print(df.isnull().sum())
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
df["Price"] = df["Price"].fillna(df["Price"].mean())
df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])
print("\nMissing values after cleaning:")
print(df.isnull().sum())
print(df.head())
df.to_csv("sales_cleaned.csv", index=False)
print("\nData cleaned successfully!")
# Out:
# Missing values before cleaning:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', ' Customer_Name', 'Order_ID', 'Order_Date', 'Product',
#        ' Category', 'Quantity', 'Price', 'Payment_Method', 'Status', 'Total'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['ID', 'Customer_Name', 'Order_ID', 'Order_Date', 'Product', 'Category',
#        'Quantity', 'Price', 'Payment_Method', 'Status', 'Total'],
#       dtype='object')

# %%
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
df.columns = df.columns.str.strip()
print(df.columns)
df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
df["Price"] = df["Price"].fillna(df["Price"].mean())
df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])
print(df.isnull().sum())
# Out:
# Index(['ID', 'Customer_Name', 'Order_ID', 'Order_Date', 'Product', 'Category',
#        'Quantity', 'Price', 'Payment_Method', 'Status', 'Total'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 print(df.columns)
#       5 df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
# ----> 6 df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
#       7 df["Price"] = df["Price"].fillna(df["Price"].mean())
#       8 df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])
#
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\series.py:6580, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6572 @doc(make_doc("median", ndim=1))
#    6573 def median(
#    6574     self,
#    (...)   6578     **kwargs,
#    6579 ):
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lekha\Downloads\messy_ecommerce_sales_data.csv")
df.columns = df.columns.str.strip()

df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df["Total"] = pd.to_numeric(df["Total"], errors="coerce")

df.loc[df["Quantity"] < 0, "Quantity"] = pd.NA

df["Category"] = df["Category"].fillna(df["Category"].mode()[0])
df["Quantity"] = df["Quantity"].fillna(df["Quantity"].median())
df["Price"] = df["Price"].fillna(df["Price"].mean())

df["Total"] = df["Total"].fillna(df["Quantity"] * df["Price"])

print(df.isnull().sum())
# Out:
# ID                0
# Customer_Name     0
# Order_ID          0
# Order_Date        0
# Product           0
# Category          0
# Quantity          0
# Price             0
# Payment_Method    0
# Status            0
# Total             0
# dtype: int64

# %%
import pandas as pd
import numpy as np
data = {
    "EmpID": [101, 102, 103, 104, 104, 105, 106, 107, 108, 109,
              110, 111, 112, 113, 114, 115, 116, 117, 118, 119],
    
    "Name": ["Arun", "Bala", "Divya", "Priya", "Priya", "Ravi",
             "Kiran", "Meena", "Suresh", "Anitha",
             "Vijay", "Sneha", "Rahul", "Deepa", "Kumar",
             "Lakshmi", "Ajay", "Nisha", "Gokul", "Pooja"],
    
    "Age": [25, np.nan, 28, 25, 25, 60,
            35, 42, np.nan, 29,
            31, 26, 40, 38, 45,
            np.nan, 30, 27, 50, 33],
    
    "Salary": [25000, 30000, np.nan, 25000, 25000, 150000,
               45000, 52000, 40000, np.nan,
               55000, 32000, 70000, 68000, 80000,
               48000, 50000, 36000, np.nan, 62000],
    
    "Department": ["HR", "IT", "HR", "HR", "HR", "Finance",
                   "IT", "Marketing", "Finance", "HR",
                   "IT", "Marketing", "Finance", "HR", "IT",
                   "Finance", "Marketing", "HR", "IT", "Finance"]
}

df = pd.DataFrame(data)
print(df)
df.to_csv("employee_data.csv", index=False)
print("\nDataset saved as employee_data.csv")
# Out:
#     EmpID     Name   Age    Salary Department
# 0     101     Arun  25.0   25000.0         HR
# 1     102     Bala   NaN   30000.0         IT
# 2     103    Divya  28.0       NaN         HR
# 3     104    Priya  25.0   25000.0         HR
# 4     104    Priya  25.0   25000.0         HR
# 5     105     Ravi  60.0  150000.0    Finance
# 6     106    Kiran  35.0   45000.0         IT
# 7     107    Meena  42.0   52000.0  Marketing
# 8     108   Suresh   NaN   40000.0    Finance
# 9     109   Anitha  29.0       NaN         HR
# 10    110    Vijay  31.0   55000.0         IT
# 11    111    Sneha  26.0   32000.0  Marketing
# 12    112    Rahul  40.0   70000.0    Finance
# 13    113    Deepa  38.0   68000.0         HR
# 14    114    Kumar  45.0   80000.0         IT
# 15    115  Lakshmi   NaN   48000.0    Finance
# 16    116     Ajay  30.0   50000.0  Marketing
# 17    117    Nisha  27.0   36000.0         HR
# 18    118    Gokul  50.0       NaN         IT
# ...

# %%
print(df.isnull())
# Out:
#     EmpID   Name    Age  Salary  Department
# 0   False  False  False   False       False
# 1   False  False   True   False       False
# 2   False  False  False    True       False
# 3   False  False  False   False       False
# 4   False  False  False   False       False
# 5   False  False  False   False       False
# 6   False  False  False   False       False
# 7   False  False  False   False       False
# 8   False  False   True   False       False
# 9   False  False  False    True       False
# 10  False  False  False   False       False
# 11  False  False  False   False       False
# 12  False  False  False   False       False
# 13  False  False  False   False       False
# 14  False  False  False   False       False
# 15  False  False   True   False       False
# 16  False  False  False   False       False
# 17  False  False  False   False       False
# 18  False  False  False    True       False
# 19  False  False  False   False       False

# %%
print(df.isnull().sum())
# Out:
# EmpID         0
# Name          0
# Age           3
# Salary        3
# Department    0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

print(df)
# Out:
#     EmpID     Name        Age         Salary Department
# 0     101     Arun  25.000000   25000.000000         HR
# 1     102     Bala  34.647059   30000.000000         IT
# 2     103    Divya  28.000000   52529.411765         HR
# 3     104    Priya  25.000000   25000.000000         HR
# 4     104    Priya  25.000000   25000.000000         HR
# 5     105     Ravi  60.000000  150000.000000    Finance
# 6     106    Kiran  35.000000   45000.000000         IT
# 7     107    Meena  42.000000   52000.000000  Marketing
# 8     108   Suresh  34.647059   40000.000000    Finance
# 9     109   Anitha  29.000000   52529.411765         HR
# 10    110    Vijay  31.000000   55000.000000         IT
# 11    111    Sneha  26.000000   32000.000000  Marketing
# 12    112    Rahul  40.000000   70000.000000    Finance
# 13    113    Deepa  38.000000   68000.000000         HR
# 14    114    Kumar  45.000000   80000.000000         IT
# 15    115  Lakshmi  34.647059   48000.000000    Finance
# ...

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
print("Duplicate Rows =", df.duplicated().sum())
# Out:
# Duplicate Rows = 1

# %%
df.drop_duplicates(inplace=True)

print(df)
# Out:
#     EmpID     Name        Age         Salary Department
# 0     101     Arun  25.000000   25000.000000         HR
# 1     102     Bala  34.647059   30000.000000         IT
# 2     103    Divya  28.000000   52529.411765         HR
# 3     104    Priya  25.000000   25000.000000         HR
# 5     105     Ravi  60.000000  150000.000000    Finance
# 6     106    Kiran  35.000000   45000.000000         IT
# 7     107    Meena  42.000000   52000.000000  Marketing
# 8     108   Suresh  34.647059   40000.000000    Finance
# 9     109   Anitha  29.000000   52529.411765         HR
# 10    110    Vijay  31.000000   55000.000000         IT
# 11    111    Sneha  26.000000   32000.000000  Marketing
# 12    112    Rahul  40.000000   70000.000000    Finance
# 13    113    Deepa  38.000000   68000.000000         HR
# 14    114    Kumar  45.000000   80000.000000         IT
# 15    115  Lakshmi  34.647059   48000.000000    Finance
# 16    116     Ajay  30.000000   50000.000000  Marketing
# ...

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Salary"] < lower) | (df["Salary"] > upper)]

print(outliers)
# Out:
#    EmpID  Name   Age    Salary Department
# 5    105  Ravi  60.0  150000.0    Finance

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["Salary"]] = scaler.fit_transform(df[["Salary"]])

print(df[["Salary"]])
# Out:
#       Salary
# 0   0.000000
# 1   0.040000
# 2   0.220235
# 3   0.000000
# 5   1.000000
# 6   0.160000
# 7   0.216000
# 8   0.120000
# 9   0.220235
# 10  0.240000
# 11  0.056000
# 12  0.360000
# 13  0.344000
# 14  0.440000
# 15  0.184000
# 16  0.200000
# 17  0.088000
# 18  0.220235
# 19  0.296000

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df["Department"] = encoder.fit_transform(df["Department"])

print(df)
# Out:
#     EmpID     Name        Age    Salary  Department
# 0     101     Arun  25.000000  0.000000           1
# 1     102     Bala  34.647059  0.040000           2
# 2     103    Divya  28.000000  0.220235           1
# 3     104    Priya  25.000000  0.000000           1
# 5     105     Ravi  60.000000  1.000000           0
# 6     106    Kiran  35.000000  0.160000           2
# 7     107    Meena  42.000000  0.216000           3
# 8     108   Suresh  34.647059  0.120000           0
# 9     109   Anitha  29.000000  0.220235           1
# 10    110    Vijay  31.000000  0.240000           2
# 11    111    Sneha  26.000000  0.056000           3
# 12    112    Rahul  40.000000  0.360000           0
# 13    113    Deepa  38.000000  0.344000           1
# 14    114    Kumar  45.000000  0.440000           2
# 15    115  Lakshmi  34.647059  0.184000           0
# 16    116     Ajay  30.000000  0.200000           3
# 17    117    Nisha  27.000000  0.088000           1
# ...

# %%
one_hot = pd.get_dummies(df["Department"])

print(one_hot)
# Out:
#         0      1      2      3
# 0   False   True  False  False
# 1   False  False   True  False
# 2   False   True  False  False
# 3   False   True  False  False
# 5    True  False  False  False
# 6   False  False   True  False
# 7   False  False  False   True
# 8    True  False  False  False
# 9   False   True  False  False
# 10  False  False   True  False
# 11  False  False  False   True
# 12   True  False  False  False
# 13  False   True  False  False
# 14  False  False   True  False
# 15   True  False  False  False
# 16  False  False  False   True
# 17  False   True  False  False
# 18  False  False   True  False
# 19   True  False  False  False

# %%
df.to_csv("cleaned_employee_data.csv", index=False)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
print(df)
# Out:
#     EmpID     Name        Age    Salary  Department
# 0     101     Arun  25.000000  0.000000           1
# 1     102     Bala  34.647059  0.040000           2
# 2     103    Divya  28.000000  0.220235           1
# 3     104    Priya  25.000000  0.000000           1
# 5     105     Ravi  60.000000  1.000000           0
# 6     106    Kiran  35.000000  0.160000           2
# 7     107    Meena  42.000000  0.216000           3
# 8     108   Suresh  34.647059  0.120000           0
# 9     109   Anitha  29.000000  0.220235           1
# 10    110    Vijay  31.000000  0.240000           2
# 11    111    Sneha  26.000000  0.056000           3
# 12    112    Rahul  40.000000  0.360000           0
# 13    113    Deepa  38.000000  0.344000           1
# 14    114    Kumar  45.000000  0.440000           2
# 15    115  Lakshmi  34.647059  0.184000           0
# 16    116     Ajay  30.000000  0.200000           3
# 17    117    Nisha  27.000000  0.088000           1
# ...
